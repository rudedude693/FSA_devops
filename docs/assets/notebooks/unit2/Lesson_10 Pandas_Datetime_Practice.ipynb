# %% [markdown]
# # https://pandas.pydata.org/docs/#

# %% [markdown]
# # Pandas Datetimes

# %%
# Import Pandas

# %% [markdown]
# ## Problem 1. Complex Date Parsing and Cleanup
#
# - You're given a messy CSV with dates in inconsistent formats:
#
# ```
# data = {
#     'raw_date': ['2023/01/01', 'Jan 2, 2023', '03-01-2023', '20230104', '05 Jan 2023']
# }
# df = pd.DataFrame(data)
# ```
#
# - Clean and convert all raw_date entries to proper datetime format.
# - Identify any invalid or missing conversions.
# - Sort the DataFrame chronologically by this new date column.

# %%
# Create the messy DataFrame with inconsistent date formats
data = {
    'raw_date': ['2023/01/01', 'Jan 2, 2023', '03-01-2023', '20230104', '05 Jan 2023']
}

# %%
# Check for any mistakes

# %%
# Sort chronologically

# %% [markdown]
# ## Problem 2. Feature Engineering from Datetime
#
#
# ```
# date_range = pd.date_range(start='2023-01-01', periods=100, freq='D')
# df = pd.DataFrame(index=date_range)
# df['visits'] = (np.random.rand(100) * 100).astype(int)
# ```
# - Extract and add new columns: day of week, is_weekend, week of the year.
# - Create a binary feature: high_traffic = 1 if visits > 75 & its a buisness day, else 0.

# %%
# Create your new features except for 'high_traffic'

# %%
# Create the 'high_traffic feature'

# %% [markdown]
# ##Problem 3. Timedelta-Based Filtering
#
#
#
# ```
# df = pd.DataFrame({
#     'user': ['Alice', 'Bob', 'Charlie'],
#     'login': ['2023-03-01 08:00', '2023-03-01 09:30', '2023-03-01 08:45'],
#     'logout': ['2023-03-01 12:15', '2023-03-01 12:00', '2023-03-01 17:00']
# })
# ```
#
# - Convert login and logout columns to datetime.
# - Calculate session durations using Timedelta.
# - Filter users whose sessions lasted **more than  hours**.

# %%
# convert the strings to datetime objects

# %%
# timedelta

# %%
# filter your dataframe

# %% [markdown]
# ## Problem 5. Business Day Offsets
#
#
# - Generate a date range starting from '2024-5-14' with 30 periods using only business days.
# - Add a new column showing delivery ETA = order date + 3 business days.

# %%
# Generate dates

# %%
# Generate the ETA column

# %% [markdown]
# ## Problem 6. Rolling, Shifting, and Comparing Time Windows
#
#
#
# - Generate a time series of daily scores over 180 days.
# - Calculate:
#   - A 7-day rolling average
#   - A column showing the percent change by day
# - Identify dates where the percent change exceeds ±15%.

# %%
# Generate your fake data

# %%
# Rolling average

# %%
# %_daily_change column

# %%
# Identify Days with large changes (>15%)
